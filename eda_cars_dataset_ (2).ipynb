# %% [markdown]
# <div style="text-align: left; background-color:black; font-family: Trebuchet MS; color:red; padding: 12px; line-height:1.25;border-radius:1px; margin-bottom: 0em; text-align: center; font-size: 58px;border-style: solid;border-color: black solid;"> CARS INDIA DATASET </div>

# %% [markdown]
# ## import

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df=pd.read_csv("Cars_India_dataset.csv")
df.head()
# Out:
#    Unnamed: 0      Model       Maker           Type  Seats  Displacement  \
# 0          24       GT-R      Nissan     Sports Car      2        3799.0
# 1          40  Scorpio-N    Mahindra            SUV      6        2000.0
# 2           2     Virtus  Volkswagen          Sedan      5        1498.0
# 3           9      Amaze       Honda  Compact Sedan      5        1199.0
# 4           8      Amaze       Honda  Compact Sedan      5        1199.0
#
#    Length  Width  Height  Wheelbase  ...  Rear Brake Drive Turning Radius  \
# 0    4710   1895    1370       2780  ...        Disc  4 WD           5.57
# 1    4662   1917    1857       2750  ...        Disc   2WD            NaN
# 2    4561   1752    1507       2651  ...        Drum   2WD           5.05
# 3    3995   1695    1501       2470  ...        Drum   2WD           4.70
# 4    3995   1695    1501       2470  ...        Drum   2WD           4.70
#
#   Fuel Tank Capacity Boot Space Fuel Efficiency Emission Type   Tyre Size  \
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0       Seats  Displacement       Length        Width  \
# count  156.000000  156.000000    155.000000   156.000000   156.000000
# mean    77.500000    5.538462   1598.109677  4324.455128  1800.512821
# std     45.177428    1.018440    504.656969   325.767389    79.050452
# min      0.000000    2.000000    799.000000  3731.000000  1579.000000
# 25%     38.750000    5.000000   1197.000000  3995.000000  1751.500000
# 50%     77.500000    5.000000   1493.000000  4315.000000  1790.000000
# 75%    116.250000    6.000000   1999.000000  4598.000000  1855.000000
# max    155.000000    9.000000   3799.000000  5115.000000  2099.000000
#
#             Height    Wheelbase  No_of_Cylinders  Turning Radius  \
# count   156.000000   156.000000       155.000000      137.000000
# mean   1653.666667  2633.358974         3.870968        5.247080
# std     125.170559   128.228372         0.389966        0.284181
# min    1370.000000  2422.000000         3.000000        4.700000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          156 non-null    int64
#  1   Model               156 non-null    object
#  2   Maker               156 non-null    object
#  3   Type                156 non-null    object
#  4   Seats               156 non-null    int64
#  5   Displacement        155 non-null    float64
#  6   Length              156 non-null    int64
#  7   Width               156 non-null    int64
#  8   Height              156 non-null    int64
#  9   Wheelbase           156 non-null    int64
#  10  No_of_Cylinders     155 non-null    float64
#  11  Fuel                156 non-null    object
#  12  Engine Type         156 non-null    object
#  13  Transmission        155 non-null    object
#  14  Front Brake         156 non-null    object
# ...

# %%
df.shape
# Out:
# (156, 25)

# %%
df.dtypes
# Out:
# Unnamed: 0              int64
# Model                  object
# Maker                  object
# Type                   object
# Seats                   int64
# Displacement          float64
# Length                  int64
# Width                   int64
# Height                  int64
# Wheelbase               int64
# No_of_Cylinders       float64
# Fuel                   object
# Engine Type            object
# Transmission           object
# Front Brake            object
# Rear Brake             object
# Drive                  object
# Turning Radius        float64
# Fuel Tank Capacity    float64
# Boot Space            float64
# Fuel Efficiency       float64
# Emission Type          object
# Tyre Size              object
# Variants                int64
# NCAP Rating            object
# dtype: object

# %% [markdown]
#    <a id='top'></a>
# <div class="list-group" id="list-tab" role="tablist"></div>
#
# ## <div style="background-color:red;font-family:sans-serif;color:#FFF9ED;font-size:150%;text-align:center;border-radius:9px 9px; padding: 15px; border-style: solid; border-color: black">DATA RENAME</div>

# %%
df.rename(columns={"Engine Type":"Engine_Type",
                   "Front Brake":"Front_Brake",
                   "Rear Brake":"Rear_Brake",
                   "Turning Radius":"Turning_Radius",
                   "Fuel Tank Capacity":"Fuel_Tank_Capacity",
                   "Boot Space":"Boot_Space",
                   "Fuel Efficiency":"Fuel_Efficiency",
                   "Emission Type":"Emission_Type",
                   "Tyre Size":"Tyre_Size",
                   "NCAP Rating":"NCAP_Rating"},inplace=True)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0             0
# Model                  0
# Maker                  0
# Type                   0
# Seats                  0
# Displacement           1
# Length                 0
# Width                  0
# Height                 0
# Wheelbase              0
# No_of_Cylinders        1
# Fuel                   0
# Engine_Type            0
# Transmission           1
# Front_Brake            0
# Rear_Brake             0
# Drive                  0
# Turning_Radius        19
# Fuel_Tank_Capacity     1
# Boot_Space            15
# Fuel_Efficiency       23
# Emission_Type          1
# Tyre_Size              0
# Variants               0
# NCAP_Rating            0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Unnamed: 0             0
# Model                  0
# Maker                  0
# Type                   0
# Seats                  0
# Displacement           1
# Length                 0
# Width                  0
# Height                 0
# Wheelbase              0
# No_of_Cylinders        1
# Fuel                   0
# Engine_Type            0
# Transmission           1
# Front_Brake            0
# Rear_Brake             0
# Drive                  0
# Turning_Radius        19
# Fuel_Tank_Capacity     1
# Boot_Space            15
# Fuel_Efficiency       23
# Emission_Type          1
# Tyre_Size              0
# Variants               0
# NCAP_Rating            0
# dtype: int64

# %%
x=df.No_of_Cylinders.mean()
df.No_of_Cylinders.fillna(x,inplace=True)

# %%
a=df.Displacement.mean()
df.Displacement.fillna(a,inplace=True)

# %%
b=df.Turning_Radius.mean()
df.Turning_Radius.fillna(b,inplace=True)

# %%
c=df.Boot_Space.mean()
df.Boot_Space.fillna(c,inplace=True)

# %%
d=df.Fuel_Efficiency.mean()
df.Fuel_Efficiency.fillna(d,inplace=True)

# %%
df.Emission_Type.dropna(inplace=True)

# %%
#df.fillna(x,inplace = True)

# %%
df.corr()
# Out:
#                     Unnamed: 0     Seats  Displacement    Length     Width  \
# Unnamed: 0            1.000000  0.213976      0.083088  0.184987  0.199385
# Seats                 0.213976  1.000000      0.359059  0.609017  0.415179
# Displacement          0.083088  0.359059      1.000000  0.707788  0.697179
# Length                0.184987  0.609017      0.707788  1.000000  0.718696
# Width                 0.199385  0.415179      0.697179  0.718696  1.000000
# Height                0.134656  0.587169      0.653001  0.540391  0.730671
# Wheelbase             0.264530  0.681153      0.583662  0.912338  0.724927
# No_of_Cylinders       0.377379  0.013669      0.527573  0.348939  0.348396
# Turning_Radius        0.289061  0.394073      0.694818  0.666736  0.641011
# Fuel_Tank_Capacity    0.097580  0.419357      0.882236  0.719217  0.706479
# Boot_Space           -0.251775 -0.071653      0.046391  0.197775  0.224342
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# Model                 0
# Maker                 0
# Type                  0
# Seats                 0
# Displacement          0
# Length                0
# Width                 0
# Height                0
# Wheelbase             0
# No_of_Cylinders       0
# Fuel                  0
# Engine_Type           0
# Transmission          1
# Front_Brake           0
# Rear_Brake            0
# Drive                 0
# Turning_Radius        0
# Fuel_Tank_Capacity    1
# Boot_Space            0
# Fuel_Efficiency       0
# Emission_Type         1
# Tyre_Size             0
# Variants              0
# NCAP_Rating           0
# dtype: int64

# %%
df.head()
# Out:
#    Unnamed: 0      Model       Maker           Type  Seats  Displacement  \
# 0          24       GT-R      Nissan     Sports Car      2        3799.0
# 1          40  Scorpio-N    Mahindra            SUV      6        2000.0
# 2           2     Virtus  Volkswagen          Sedan      5        1498.0
# 3           9      Amaze       Honda  Compact Sedan      5        1199.0
# 4           8      Amaze       Honda  Compact Sedan      5        1199.0
#
#    Length  Width  Height  Wheelbase  ...  Rear_Brake Drive Turning_Radius  \
# 0    4710   1895    1370       2780  ...        Disc  4 WD        5.57000
# 1    4662   1917    1857       2750  ...        Disc   2WD        5.24708
# 2    4561   1752    1507       2651  ...        Drum   2WD        5.05000
# 3    3995   1695    1501       2470  ...        Drum   2WD        4.70000
# 4    3995   1695    1501       2470  ...        Drum   2WD        4.70000
#
#   Fuel_Tank_Capacity Boot_Space Fuel_Efficiency Emission_Type   Tyre_Size  \
# ...

# %%
df.Model.value_counts()
# Out:
# Scorpio-N            10
# XUV 700               9
# Carens                8
# Seltos                8
# Alcazar               8
# Fortuner              6
# Sonet                 5
# Creta                 5
# Verna                 5
# i20                   5
# Venue                 4
# Kiger                 4
# Amaze                 4
# XUV 300               4
# Grand i10 Nios        4
# Thar LX               4
# Safari                4
# Taigun                4
# Aura                  4
# Tucson                3
# Carnival              3
# Kicks                 3
# Magnite               3
# Kwid                  3
# Virtus                3
# City 5th Gen          3
# i20 N-Line            2
# Glanza                2
# Urban Cruiser         2
# C3                    2
# Fortuner Legender     2
# Triber                2
# Thar AX OPT           2
# Jazz                  2
# WR-V                  2
# Scorpio Classic       2
# Harrier               2
# GT-R                  1
# ...

# %% [markdown]
# ## Data Visulization / EDA

# %%
sns.pairplot(df)
plt.show()

# %%
cormat=df.corr()
top_corr_features = cormat.index
plt.subplots(figsize=(9, 9))
sns.heatmap(df[top_corr_features].corr(), annot = True, cmap ="mako",fmt='.2')
plt.show()

# %%
data1 = df['Model']
data2= df['Maker']
conc_data_col = pd.concat([data1,data2],axis =1) # axis = 1 : adds dataframes in column
conc_data_col
# Out:
#              Model       Maker
# 0             GT-R      Nissan
# 1        Scorpio-N    Mahindra
# 2           Virtus  Volkswagen
# 3            Amaze       Honda
# 4            Amaze       Honda
# ..             ...         ...
# 151        Magnite      Nissan
# 152        Magnite      Nissan
# 153        Magnite      Nissan
# 154         Virtus  Volkswagen
# 155  Kona Electric     Hyundai
#
# [156 rows x 2 columns]

# %%
a,ax=plt.subplots(figsize=(12,12))
sns.countplot(data=df,x="Model", saturation=.75, dodge=False,ax=ax,palette="terrain")
plt.xticks(rotation=90)
plt.xlabel("Car's Model",fontsize=20,color="blue")
plt.show()

# %%
labels = df["Model"].value_counts().index
sizes = df["Model"].value_counts()
plt.figure(figsize = (10,10))
plt.pie(sizes, labels=labels, rotatelabels=False, autopct='%1.1f%%')
plt.title('Model',color = 'purple',fontsize = 15)
plt.show()

# %%
df.Type.value_counts()
# Out:
# SUV              71
# Compact SUV      25
# Hatchback        20
# Sedan            13
# MUV              10
# Compact Sedan     8
# MPV               4
# Mid Size SUV      4
# Sports Car        1
# Name: Type, dtype: int64

# %%
a,ax=plt.subplots(figsize=(12,12))
sns.countplot(data=df,x="Type", saturation=.75, dodge=False,ax=ax,palette="Set2_r")
plt.xticks(rotation=90)
plt.xlabel("Car's Type",fontsize=20,color="pink")
plt.show()

# %%
labels = df["Type"].value_counts().index
sizes = df["Type"].value_counts()
plt.figure(figsize = (10,10))
plt.pie(sizes, labels=labels, rotatelabels=False, autopct='%1.1f%%')
plt.title('Type',color = 'purple',fontsize = 15)
plt.show()

# %%
df.Seats.value_counts()
# Out:
# 5    98
# 7    34
# 6    14
# 4     6
# 9     2
# 2     1
# 8     1
# Name: Seats, dtype: int64

# %%
a,ax=plt.subplots(figsize=(6,6))
sns.countplot(data=df,x="Seats", saturation=.75, dodge=False,ax=ax,palette="twilight_shifted")
plt.xticks(rotation=90)
plt.xlabel("Car's Seats",fontsize=20,color="orange")
plt.show()

# %%
df.head(2)
# Out:
#    Unnamed: 0      Model     Maker        Type  Seats  Displacement  Length  \
# 0          24       GT-R    Nissan  Sports Car      2        3799.0    4710
# 1          40  Scorpio-N  Mahindra         SUV      6        2000.0    4662
#
#    Width  Height  Wheelbase  ...  Rear_Brake Drive Turning_Radius  \
# 0   1895    1370       2780  ...        Disc  4 WD        5.57000
# 1   1917    1857       2750  ...        Disc   2WD        5.24708
#
#   Fuel_Tank_Capacity Boot_Space Fuel_Efficiency Emission_Type   Tyre_Size  \
# 0               74.0      315.0       10.160000        Euro 6   285/35/20
# 1               57.0      460.0       18.028947         BS VI  255/16 R18
#
#    Variants  NCAP_Rating
# 0         1   Not Tested
# 1         1    Not Rated
#
# [2 rows x 25 columns]

# %%
df.Rear_Brake.value_counts()
# Out:
# Disc    79
# Drum    77
# Name: Rear_Brake, dtype: int64

# %%
a,ax=plt.subplots(figsize=(6,6))
sns.countplot(data=df,x="Rear_Brake", saturation=.75, dodge=False,ax=ax,palette="twilight_shifted")
plt.xticks(rotation=90)
plt.xlabel("Car's Rear Brake",fontsize=20,color="brown")
plt.show()

# %%
df.NCAP_Rating.value_counts()
# Out:
# 5             36
# 3             36
# 4             33
# Not Rated     28
# 2              7
# 6              6
# Not Tested     5
# 0              5
# Name: NCAP_Rating, dtype: int64

# %%
a,ax=plt.subplots(figsize=(6,6))
sns.countplot(data=df,x="NCAP_Rating", saturation=.75, dodge=False,ax=ax,palette="crest_r")
plt.xticks(rotation=90)
plt.xlabel("Car's NCAP Rating",fontsize=20,color="green")
plt.show()

# %%
df.head()
# Out:
#    Unnamed: 0      Model       Maker           Type  Seats  Displacement  \
# 0          24       GT-R      Nissan     Sports Car      2        3799.0
# 1          40  Scorpio-N    Mahindra            SUV      6        2000.0
# 2           2     Virtus  Volkswagen          Sedan      5        1498.0
# 3           9      Amaze       Honda  Compact Sedan      5        1199.0
# 4           8      Amaze       Honda  Compact Sedan      5        1199.0
#
#    Length  Width  Height  Wheelbase  ...  Rear_Brake Drive Turning_Radius  \
# 0    4710   1895    1370       2780  ...        Disc  4 WD        5.57000
# 1    4662   1917    1857       2750  ...        Disc   2WD        5.24708
# 2    4561   1752    1507       2651  ...        Drum   2WD        5.05000
# 3    3995   1695    1501       2470  ...        Drum   2WD        4.70000
# 4    3995   1695    1501       2470  ...        Drum   2WD        4.70000
#
#   Fuel_Tank_Capacity Boot_Space Fuel_Efficiency Emission_Type   Tyre_Size  \
# ...

# %%
sns.scatterplot(x = df.Length, y = df.Width, hue = df.Height,palette="turbo")
plt.show()

# %%
a,ax=plt.subplots(figsize=(16,16))
sns.barplot(data=df,x="Seats",y="Maker", saturation=.75, dodge=False,ax=ax,palette="ocean")
plt.xticks(rotation=90)
plt.xlabel("Seats",fontsize=20,color="cyan")
plt.show()
